# %%
from langchain import PromptTemplate

import hgutils
import time

stopwatch = hgutils.timer("Personal Shopper")

# %%
#Data
categories = ['mobile', 'grocery', 'fashion']
products = ['iPhone 14 Pro', 'Samsung Galaxy S23 Ultra', 'Google Pixel 7']
product_specs = [{'product name': 'Apple iPhone 14 Pro',
                    'NETWORK Technology': 'GSM / CDMA / HSPA / EVDO / LTE / 5G',
                    'SIM Type': 'Dual SIM',
                    'LAUNCHED': '07 Sept 2022',
                    'BODY Dimensions': '147.5 x 71.5 x 7.9 mm',
                    'BODY Weight': '206 g',
                    'BODY Rating': 'IP68 dust/water resistant',
                    'DISPLAY Type': 'LTPO Super Retina XDR OLED',
                    'DISPLAY Refresh Rate': '120Hz, more is better',
                    'DISPLAY Size': '6.1 inches',
                    'PLATFORM OS': 'iOS 16',
                    'Chipset': 'Apple A16 Bionic',
                    'CAMERA Front': '1',
                    'BATTERY\tCapacity': '3200 mAh, more is better',
                    'BATTERY Life': '86 hours, more is better',
                    'WIRELESS Charging': 'True',
                    'COLORS Available': 'Space Black, Silver, Gold, Deep Purple',
                    'Price': '₹ 120000',
                    'Discount': 'Maximum 10%',
                    'Delivery Time': '5 days'},
                    {'product name': 'Samsung Galaxy S23 Ultra',
                    'NETWORK Technology': 'GSM / CDMA / HSPA / EVDO / LTE / 5G',
                    'SIM Type': 'Dual SIM',
                    'LAUNCHED': '03 Feb 2023',
                    'BODY Dimensions': '163.4 x 78.1 x 8.9 mm',
                    'BODY Weight': '234 g',
                    'BODY Rating': 'IP68 dust/water resistant',
                    'DISPLAY Type': 'Dynamic AMOLED 2X',
                    'DISPLAY Refresh Rate': '120Hz, more is better',
                    'DISPLAY Size': '6.8 inches',
                    'PLATFORM OS': 'Android 13',
                    'Chipset': 'Qualcomm Snapdragon 8 Gen 2 (4 nm)',
                    'CAMERA Front': '4',
                    'BATTERY\tCapacity': '5000 mAh, more is better',
                    'BATTERY Life': '126 hours, more is better',
                    'WIRELESS Charging': 'True',
                    'COLORS Available': 'Phantom Black, Green, Cream, Lavender, Graphite, Sky Blue, Lime, Red',
                    'Price': '₹ 100000',
                    'Discount': 'Maximum 5%',
                    'Delivery Time': '2 days'},
                    {'product name': 'Google Pixel 7 Pro',
                    'NETWORK Technology': 'GSM / CDMA / HSPA / EVDO / LTE / 5G',
                    'SIM Type': 'Dual SIM',
                    'LAUNCHED': '06 Oct 2022',
                    'BODY Dimensions': '162.9 x 76.6 x 8.9 mm',
                    'BODY Weight': '234 g',
                    'BODY Rating': 'IP68 dust/water resistant',
                    'DISPLAY Type': 'LTPO AMOLED',
                    'DISPLAY Refresh Rate': '120Hz, more is better',
                    'DISPLAY Size': '6.7 inches',
                    'PLATFORM OS': 'Android 13',
                    'Chipset': 'Google Tensor G2',
                    'CAMERA Front': '3',
                    'BATTERY\tCapacity': '5000 mAh, more is better',
                    'BATTERY Life': '83 hours, more is better',
                    'WIRELESS Charging': 'True',
                    'COLORS Available': 'Obsidian Black, Snow White, Hazel Green',
                    'Price': '₹ 80000',
                    'Discount': 'Maximum 5%',
                    'Delivery Time': '3 days'}]

# %%
#Rules
answering_rules = ['Restrict you suggestion to above mentioned products only.',
                   "Always have a definite answer even if the confidence is low",
                   "Answer in fun way",
                   "Always be closing",
                   ]

# %%
#Conversation
conversation_history = []

def add_message(conversation_history,message,sender):
    conversation_history.append(f"{sender}: {message}")

def conversation_history_text(conversation_history):
    s = ""
    for list_item in enumerate(conversation_history_text):
        s += f"{list_item}\n"
    return s

# %%
def list_to_string(list,ordered=True,separator="\n"):
    s = ""
    for idx,list_item in enumerate(list):
        if ordered:
            s += f"{idx+1}.\t{list_item} \n"
        else:
            s += f"-.\t{list_item} \n"
    return s

def products_to_string(products_with_specs):
    output_string = ""
    for p in products_with_specs:
        product_string = ""
        for k,v in p.items():
            if k == "product name":
                product_string += v
            else:
                product_string += f"""\n\t{k} = {v}"""
        output_string += f"""{product_string}\n\n\n"""
    return output_string
# Out:
# ''

# %%
singular_prompt = f'''
You are an AI based shopping assistant of a store named Tata Neu. 

The store offers products in following categories:
{list_to_string(categories)}

Grocery and Fashion categories are currently under production. The store is currently not offering any products under Fashion and grocery category.
Mobile Category have three mobile phones. The mobile and its specs are mentioned below:
{products_to_string(product_specs)}


Here's a conversation between you and customer:
{conversation_history_text(conversation_history)}
Customer: {{query}}


Please answer following question based on above conversation
1. What is your response to customer query
2. Restrict you answer to "Yes" or "No" only without any further explanation. Is the customer is ready to buy the product unconditionally? Answer yes only if confidence is above 90% else No.
3. If the Answer to second question is "Yes", provide this payment link "mock_payment_link.com" to customer and respectfully ask them to make the payment.
4. Restrict you answer to "Yes","No" or "N/A" only without any further explanation. Is the customer is ready to buy the product but on certain conditions, will the store be able to meet those conditions?
5. If the Answer to forth question is No, reply to decline customers conditions in polite way. You can suggest an alternate product if that is helpful.


Answer in following format:
{{{{"response":answer to question 1,
"response_confidence":your confidence response to question 1,
"purchase_ready": answer to question 2,
"purchase_ready_confidence": confidence on response to question 2,
"purchase_reply": answer to question 3,
"purchase_ready_confidence": confidence on response to question 3,
"conditional_purchase": answer to question 4,
"conditional_purchase_confidence": confidence on response to question 4,
"conditional_purchase_reply": answer to question 5,
"conditional_purchase_reply_confidence": confidence on response to question 5,
}}}}


Follow following rules before answering
{list_to_string(answering_rules)}
'''
print(singular_prompt)
# Out:
# You are a personal shopper of a store named Tata Neu.
#
# The store offers products in following categories:
# 1.	mobile
# 2.	grocery
# 3.	fashion
#
#
# Grocery and Fashion categories are currently under production. The store is currently not offering any products under Fashion and grocery category.
# Mobile Category have three mobile phones. The mobile and its specs are mentioned below:
# Apple iPhone 14 Pro
# 	NETWORK Technology = GSM / CDMA / HSPA / EVDO / LTE / 5G
# 	SIM Type = Dual SIM
# 	LAUNCHED = 07 Sept 2022
# 	BODY Dimensions = 147.5 x 71.5 x 7.9 mm
# 	BODY Weight = 206 g
# 	BODY Rating = IP68 dust/water resistant
# 	DISPLAY Type = LTPO Super Retina XDR OLED
# 	DISPLAY Refresh Rate = 120Hz, more is better
# 	DISPLAY Size = 6.1 inches
# 	PLATFORM OS = iOS 16
# 	Chipset = Apple A16 Bionic
# 	CAMERA Front = 1
# 	BATTERY	Capacity = 3200 mAh, more is better
# 	BATTERY Life = 86 hours, more is better
# 	WIRELESS Charging = True
# ...

# %%
# Out:
# ['mobile', 'grocery', 'fashion']

# %%
moods
# Out:
# ['joking', 'formal', 'informal', 'fun', 'energetic']

# %%
purchase_template = f'''
You are a personal shopper of a store named Tata Neu.
The store offers following products:
{list_to_string(products)}

The customer is seeking to purchase a product in below customer query, you job is to identify:
1. What product is the customer referring to? If customer is referring to more than one product mention all products separated by commas.
2. Your confidence on answer to question 1 in percentage
3. What is the mood of the customer?

Restrict your answer in following format:

{{{{product: answer to question 1,
product_confidence: answer to question 2,
mood: answer to question 3}}}}

Customer Query:
{{query}}
'''

purchase_prompt = PromptTemplate(input_variables=['query'],template=purchase_template)
query = "Hi I want to buy an iPhone"
prompt = purchase_prompt.format(query=query)
print(prompt)
# Out:
# You are a personal shopper of a store named Tata Neu.
# The store offers following products:
# 1.	iPhone 14
# 2.	Samsung Galaxy S23 Ultra
# 3.	One Plus 12
#
#
# The customer is seeking to purchase a product in below customer query, you job is to identify:
# 1. What product is the customer referring to? If customer is referring to more than one product mention all products separated by commas.
# 2. Your confidence on answer to question 1 in percentage
# 3. What is the mood of the customer?
#
# Restrict your answer in following format:
#
# {product: answer to question 1,
# product_confidence: answer to question 2,
# mood: answer to question 3}
#
# Customer Query:
# Hi I want to buy an iPhone

# %%
alternate_products_template = f'''
You are a personal shopper of a store named Tata Neu.
The store offers following products:
{list_to_string(products)}

The customer is seeking alternates of a product in below customer query, you job is to identify:
1. What product is the customer referring to? If customer is referring to more than one product mention all products separated by commas.
2. Your confidence on answer to question 1 in percentage
3. What is the mood of the customer?

Restrict your answer in following format:

{{product: answer to question 1,
product_confidence: answer to question 2,
mood: answer to question 3}}

Customer Query:
{{query}}
'''

# print(alternate_products_template)

# %%
delivery_time_template = f'''
You are a personal shopper of a store named Tata Neu.
The store offers following products:
{list_to_string(products)}

The customer is seeking delivery time of a product in below customer query, you job is to identify:
1. What product is the customer referring to? If customer is referring to more than one product mention all products separated by commas.
2. Your confidence on answer to question 1 in percentage
3. What is the mood of the customer?

Restrict your answer in following format:

{{product: answer to question 1,
product_confidence: answer to question 2,
mood: answer to question 3}}

Customer Query:
{{query}}
'''

# print(delivery_time_template)

# %%
comparison_template = f'''
You are a personal shopper of a store named Tata Neu.
The store offers following products:
{list_to_string(products)}

The customer is seeking comparison of different products in below customer query, you job is to identify:
1. What products is the customer referring to? If customer is referring to more than one product mention all products separated by commas.
2. Your confidence on answer to question 1 in percentage
3. Any specific description of products the customer is referring to. In case of multiple description, mention all separated with commas. If not specific description is referred reply with NA.
4. Your confidence on answer to question 3 in percentage
5. What is the mood of the customer?

Restrict your answer in following format:

{{product: answer to question 1,
product_confidence: answer to question 2,
description: answer to question 3
description_confidence: answer to question 4
mood: answer to question 5}}

Customer Query:
{{query}}
'''

# print(comparison_template)

# %%
product_description_template = f'''
You are a personal shopper of a store named Tata Neu.
The store offers following products:
{list_to_string(products)}

The customer is seeking description of a product in below customer query, you job is to identify:
1. What product is the customer referring to? If customer is referring to more than one product mention all products separated by commas.
2. Your confidence on answer to question 1 in percentage
3. What is the mood of the customer?

Restrict your answer in following format:

{{product: answer to question 1,
product_confidence: answer to question 2,
mood: answer to question 3}}

Customer Query:
{{query}}
'''

# print(product_description_template)

# %%
review_template = f'''
You are a personal shopper of a store named Tata Neu.
The store offers following products:
{list_to_string(products)}

The customer is seeking reviews of a product in below customer query, you job is to identify:
1. What product is the customer referring to? If customer is referring to more than one product mention all products separated by commas.
2. Your confidence on answer to question 1 in percentage
3. Any specific description of product the customer is referring to. In case of multiple description, mention all separated with commas. If not specific description is referred reply with NA.
4. Your confidence on answer to question 3 in percentage
5. What is the mood of the customer?

Restrict your answer in following format:

{{product: answer to question 1,
product_confidence: answer to question 2,
description: answer to question 3
description_confidence: answer to question 4
mood: answer to question 5}}

Customer Query:
{{query}}
'''

# print(review_template)

# %%
first_template = f'''
You are a personal shopper of a store named Tata Neu. 

The store offers products in following categories:
{list_to_string(categories)}

The store also provides following details related to it products:
{list_to_string(details)}

Based on below customer query, your job is to identify:
1. What category the customer is looking for based on the above list? If identified category is not in above list reply with NA.
2. Your confidence on answer to question 1 in percentage
3. What details the customer is interested in based on the above list? If there are more than one detail, mention all details separated by commas. If identified detail is not in above list reply with NA.
4. Your confidence on answer to question 3 in percentage. In case of multiple details mention the confidence percentage for all separated by commas.
5. What is the mood of the customer?

Restrict your answer in following format:

{{Category: answer to question 1,
category_confidence: answer to question 2,
detail: answer to question 3
detail_confidence: answer to question 4
mood: answer to question 5}}

Customer Query:
{{query}}
'''

print(first_template)
# Out:
# You are a personal shopper of a store named Tata Neu.
#
# The store offers products in following categories:
# 1.	mobile
# 2.	grocery
#
#
# The store also provides following details related to it products:
# 1.	reviews
# 2.	product description
# 3.	comparison
# 4.	delivery time
# 5.	alternate products
# 6.	purchase
# 7.	recommendation
#
#
# Based on below customer query, your job is to identify:
# 1. What category the customer is looking for based on the above list? If identified category is not in above list reply with NA.
# 2. Your confidence on answer to question 1 in percentage
# 3. What details the customer is interested in based on the above list? If there are more than one detail, mention all details separated by commas. If identified detail is not in above list reply with NA.
# 4. Your confidence on answer to question 3 in percentage. In case of multiple details mention the confidence percentage for all separated by commas.
# 5. What is the mood of the customer?
#
# ...

# %%
greet_template = '''You are a personal shopper of a store named Tata Neu. 
The store offers products in following categories:
1.	mobile 
2.	grocery 

The customer asked a query and you were not able to understand what they meant so:

Reply with following:
1. Apologize the customer for not understanding their request.
2. Request customer to ask queries related to the categories of the store

Reply in a {mood} way'''
